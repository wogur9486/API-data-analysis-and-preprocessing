# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %% [markdown]
# # 종합유원시설업.csv 불러오기

# %%
file = pd.read_csv('data/종합유원시설업.csv', encoding='cp949')
file.head()
# Out:
#    번호   개방서비스명    개방서비스아이디  개방자치단체코드                  관리번호       인허가일자  \
# 0   1  종합유원시설업  03_07_12_P   3480000  CDFI5271002005000001  2005-07-22
# 1   2  종합유원시설업  03_07_12_P   5090000  CDFI5271002008000001  2008-07-18
# 2   3  종합유원시설업  03_07_12_P   3820000  CDFI5271002018000001  2018-06-20
# 3   4  종합유원시설업  03_07_12_P   4281000  CDFI5271002008000001  2008-06-12
# 4   5  종합유원시설업  03_07_12_P   5380000  CDFI5271001993000001  1993-04-30
#
#   인허가취소일자  영업상태구분코드 영업상태명  상세영업상태코드  ... 의무실유무 안내소유무 기획여행보험시작일자 기획여행보험종료일자  \
# 0     NaN         2    휴업         2  ...     N     Y        NaN        NaN
# 1     NaN         2    휴업         2  ...     Y     Y        NaN        NaN
# 2     NaN         2    휴업         2  ...     Y     Y        NaN        NaN
# 3     NaN         2    휴업         2  ...   NaN   NaN        NaN        NaN
# 4     NaN         2    휴업         2  ...     Y     Y        NaN        NaN
#
#    자본금 보험시작일자  보험종료일자 부대시설내역     시설규모 Unnamed: 63
# ...

# %% [markdown]
# # 필요한 컬럼만 갖고오기

# %%
file2 = file.loc[:,['영업상태명', '상세영업상태코드', '상세영업상태명', '소재지전화', '소재지전체주소', '도로명전체주소', '사업장명']]

# %%
file2
# Out:
#              영업상태명  상세영업상태코드 상세영업상태명           소재지전화  \
# 0               휴업         2      휴업    053-608-5000
# 1               휴업         2      휴업    054-630-5500
# 2               휴업         2      휴업    031-894-0357
# 3               휴업         2      휴업    033-330-6000
# 4               휴업         2      휴업        379-7125
# ..             ...       ...     ...             ...
# 73  취소/말소/만료/정지/중지        30    허가취소    041)939-9000
# 74  취소/말소/만료/정지/중지        30    허가취소  055-223-9561~5
# 75  취소/말소/만료/정지/중지        30    허가취소             NaN
# 76  취소/말소/만료/정지/중지        30    허가취소     02-454-4442
# 77  취소/말소/만료/정지/중지        30    허가취소        223-5118
#
#                                 소재지전체주소                           도로명전체주소  \
# 0                대구광역시 달성군 가창면 냉천리 27-9             대구광역시 달성군 가창면 가창로 891
# 1                    경상북도 영주시 아지동 산 6번지            경상북도 영주시 회헌로 434 (아지동)
# 2            경기도 의정부시 장암동 135 아일랜드캐슬 A동  경기도 의정부시 장곡로 22, 아일랜드캐슬 A동 (장암동)
# ...

# %% [markdown]
# # 영업중인 사업장만 갖고오기

# %%
file3 = file2.loc[file2['상세영업상태코드']==13]

# %% [markdown]
# # nan값을 공백으로 바꾸기

# %%
#file3 = file3.fillna("")

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 27 to 72
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   영업상태명     46 non-null     object
#  1   상세영업상태코드  46 non-null     int64
#  2   상세영업상태명   46 non-null     object
#  3   소재지전화     38 non-null     object
#  4   소재지전체주소   46 non-null     object
#  5   도로명전체주소   45 non-null     object
#  6   사업장명      46 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %%
file3
# Out:
#     영업상태명  상세영업상태코드 상세영업상태명          소재지전화  \
# 27  영업/정상        13     영업중   053-620-0001
# 28  영업/정상        13     영업중   051-954-8840
# 29  영업/정상        13     영업중       451-8500
# 30  영업/정상        13     영업중   041-560-9114
# 31  영업/정상        13     영업중  070-7433-3150
# 32  영업/정상        13     영업중   041-539-2000
# 33  영업/정상        13     영업중   041-930-2100
# 34  영업/정상        13     영업중       320-8466
# 35  영업/정상        13     영업중       320-8261
# 36  영업/정상        13     영업중   031-286-2111
# 37  영업/정상        13     영업중      1833-9810
# 38  영업/정상        13     영업중  070-7113-6133
# 39  영업/정상        13     영업중   054-778-9027
# 40  영업/정상        13     영업중  031-8072-8802
# 41  영업/정상        13     영업중   031-945-2250
# 42  영업/정상        13     영업중   031-880-3820
# 43  영업/정상        13     영업중   061-808-5846
# 44  영업/정상        13     영업중            NaN
# 45  영업/정상        13     영업중            NaN
# 46  영업/정상        13     영업중       252-7226
# 47  영업/정상        13     영업중   033-815-2300
# ...

# %%
file4 = file3.copy()

# %% [markdown]
# # 비어있는 도로명주소를 소재지전체주소에서 값 끌어오기

# %%
file3.fillna("")
# Out:
#     영업상태명  상세영업상태코드 상세영업상태명          소재지전화  \
# 27  영업/정상        13     영업중   053-620-0001
# 28  영업/정상        13     영업중   051-954-8840
# 29  영업/정상        13     영업중       451-8500
# 30  영업/정상        13     영업중   041-560-9114
# 31  영업/정상        13     영업중  070-7433-3150
# 32  영업/정상        13     영업중   041-539-2000
# 33  영업/정상        13     영업중   041-930-2100
# 34  영업/정상        13     영업중       320-8466
# 35  영업/정상        13     영업중       320-8261
# 36  영업/정상        13     영업중   031-286-2111
# 37  영업/정상        13     영업중      1833-9810
# 38  영업/정상        13     영업중  070-7113-6133
# 39  영업/정상        13     영업중   054-778-9027
# 40  영업/정상        13     영업중  031-8072-8802
# 41  영업/정상        13     영업중   031-945-2250
# 42  영업/정상        13     영업중   031-880-3820
# 43  영업/정상        13     영업중   061-808-5846
# 44  영업/정상        13     영업중
# 45  영업/정상        13     영업중
# 46  영업/정상        13     영업중       252-7226
# 47  영업/정상        13     영업중   033-815-2300
# 48  영업/정상        13     영업중
# ...

# %%
file3["도로명전체주소"].fillna(file3['소재지전체주소'], inplace=True)
# Out:
# /var/folders/22/c_58xyrx5_3g8md1gqx1zz8r0000gn/T/ipykernel_20942/1611772268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file3["도로명전체주소"].fillna(file3['소재지전체주소'], inplace=True)

# %%
file3
# Out:
#     영업상태명  상세영업상태코드 상세영업상태명          소재지전화  \
# 27  영업/정상        13     영업중   053-620-0001
# 28  영업/정상        13     영업중   051-954-8840
# 29  영업/정상        13     영업중       451-8500
# 30  영업/정상        13     영업중   041-560-9114
# 31  영업/정상        13     영업중  070-7433-3150
# 32  영업/정상        13     영업중   041-539-2000
# 33  영업/정상        13     영업중   041-930-2100
# 34  영업/정상        13     영업중       320-8466
# 35  영업/정상        13     영업중       320-8261
# 36  영업/정상        13     영업중   031-286-2111
# 37  영업/정상        13     영업중      1833-9810
# 38  영업/정상        13     영업중  070-7113-6133
# 39  영업/정상        13     영업중   054-778-9027
# 40  영업/정상        13     영업중  031-8072-8802
# 41  영업/정상        13     영업중   031-945-2250
# 42  영업/정상        13     영업중   031-880-3820
# 43  영업/정상        13     영업중   061-808-5846
# 44  영업/정상        13     영업중            NaN
# 45  영업/정상        13     영업중            NaN
# 46  영업/정상        13     영업중       252-7226
# 47  영업/정상        13     영업중   033-815-2300
# ...

# %% [markdown]
# # 새로운 "분류" 컬럼 생성하기

# %%
file3 = file3.drop(['영업상태명', '상세영업상태코드', '상세영업상태명', '소재지전화', '소재지전체주소'], axis=1)

# %%
file3['분류'] = "테마파크"
file3
# Out:
#                                          도로명전체주소  \
# 27                     대구광역시 달서구 두류공원로 200 (두류동)
# 28       부산광역시 해운대구 달맞이길 30, 포디움동 3,4층 (중동, 엘시티)
# 29                       경상북도 구미시 금오산로 341 (남통동)
# 30                      충청남도 천안시 동남구 수신면 수신로 576
# 31                   충청남도 천안시 동남구 성남면 종합휴양지로 200
# 32                    충청남도 아산시 음봉면 아산온천로157번길 67
# 33                        충청남도 보령시 대해로 876 (신흑동)
# 34                     경기도 용인시 처인구 포곡읍 에버랜드로 199
# 35                     경기도 용인시 처인구 포곡읍 에버랜드로 199
# 36                     경기도 용인시 기흥구 민속촌로 90 (보라동)
# 37         제주특별자치도 제주시 애월읍 천덕로 880-24, 애월스마트테마파크
# 38                        경상북도 경주시 보문로 544 (천군동)
# 39          경상북도 경주시 보불로 391 (천군동, 디아너스C.C.골프클럽)
# 40                경기도 하남시 미사대로 750 (신장동, 스타필드하남)
# 41                 경기도 파주시 조리읍 장곡로 218, 하니랜드놀이동산
# 42                경기도 여주시 강변유원지길 45 (연양동, 선밸리호텔)
# 43                         전라남도 여수시 소라면 안심산길 155
# 44               강원특별자치도 횡성군 둔내면 고원로 451, 웰리힐리파크
# ...

# %%
file3.columns = ['city', 'place_name', 'category']

# %%
file3
# Out:
#                       place_name place_desc category  \
# 0                            이월드                테마파크
# 1   클럽디오아시스(CLUBD OASIS) 스파&워터파크                테마파크
# 2                           금오랜드                테마파크
# 3                           상록랜드                테마파크
# 4                         소노벨 천안                테마파크
# 5                 (주)금호리조트아산스파비스                테마파크
# 6                       호텔마스타 대천                테마파크
# 7                           에버랜드                테마파크
# 8                         캐리비안베이                테마파크
# 9                     한국민속촌 가족공원                테마파크
# 10                9.81 PARK JEJU                테마파크
# 11               경주월드주식회사 (경주지점)                테마파크
# 12                      블루원 워터파크                테마파크
# 13                      아쿠아필드 하남                테마파크
# 14                          하니랜드                테마파크
# 15                      주식회사 썬밸리                테마파크
# 16                     유월드루지테마파크                테마파크
# ...

# %%
file3.to_csv("data/pj1_amusementpark_01.csv", encoding='cp949')

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 27 to 72
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        46 non-null     object
#  1   place_name  46 non-null     object
#  2   category    46 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %%
file3 = file3.reset_index(drop=True)

# %%
file3
# Out:
#                                             city  \
# 0                      대구광역시 달서구 두류공원로 200 (두류동)
# 1        부산광역시 해운대구 달맞이길 30, 포디움동 3,4층 (중동, 엘시티)
# 2                        경상북도 구미시 금오산로 341 (남통동)
# 3                       충청남도 천안시 동남구 수신면 수신로 576
# 4                    충청남도 천안시 동남구 성남면 종합휴양지로 200
# 5                     충청남도 아산시 음봉면 아산온천로157번길 67
# 6                         충청남도 보령시 대해로 876 (신흑동)
# 7                      경기도 용인시 처인구 포곡읍 에버랜드로 199
# 8                      경기도 용인시 처인구 포곡읍 에버랜드로 199
# 9                      경기도 용인시 기흥구 민속촌로 90 (보라동)
# 10         제주특별자치도 제주시 애월읍 천덕로 880-24, 애월스마트테마파크
# 11                        경상북도 경주시 보문로 544 (천군동)
# 12          경상북도 경주시 보불로 391 (천군동, 디아너스C.C.골프클럽)
# 13                경기도 하남시 미사대로 750 (신장동, 스타필드하남)
# 14                 경기도 파주시 조리읍 장곡로 218, 하니랜드놀이동산
# 15                경기도 여주시 강변유원지길 45 (연양동, 선밸리호텔)
# 16                         전라남도 여수시 소라면 안심산길 155
# 17               강원특별자치도 횡성군 둔내면 고원로 451, 웰리힐리파크
# ...

# %% [markdown]
# # sql에 넣기

# %%
import pymysql

# %%
conn = pymysql.connect(host='192.168.0.103', user='user1', password='u1234', db='project01', charset='utf8')
cur=conn.cursor()

# %%
file3 = file3[['place_name', 'category', 'city']]

# %%
file3['place_desc'] = ""
file3['rating'] = 0
file3['num_reviews'] = 0

# %%
file3 = file3[['place_name', 'place_desc', 'category', 'city', 'rating', 'num_reviews']]

# %%
file3
# Out:
#                       place_name place_desc category  \
# 0                            이월드                테마파크
# 1   클럽디오아시스(CLUBD OASIS) 스파&워터파크                테마파크
# 2                           금오랜드                테마파크
# 3                           상록랜드                테마파크
# 4                         소노벨 천안                테마파크
# 5                 (주)금호리조트아산스파비스                테마파크
# 6                       호텔마스타 대천                테마파크
# 7                           에버랜드                테마파크
# 8                         캐리비안베이                테마파크
# 9                     한국민속촌 가족공원                테마파크
# 10                9.81 PARK JEJU                테마파크
# 11               경주월드주식회사 (경주지점)                테마파크
# 12                      블루원 워터파크                테마파크
# 13                      아쿠아필드 하남                테마파크
# 14                          하니랜드                테마파크
# 15                      주식회사 썬밸리                테마파크
# 16                     유월드루지테마파크                테마파크
# ...

# %%
for index, row in file3.iterrows():
    cur.execute("""
        INSERT INTO places(
            place_name,
            place_desc,
            category,
            city,
            rating,
            num_reviews) VALUES (%s, %s, %s, %s, %s, %s)""",
        (row['place_name'],
         row['place_desc'],
         row['category'],
         row['city'],
         row['rating'],
         row['num_reviews']))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
#       1 for index, row in file3.iterrows():
# ----> 2     cur.execute("""
#       3         INSERT INTO places(
#       4             place_name,
#       5             place_desc,
#       6             category,
#       7             city,
#       8             rating,
#       9             num_reviews) VALUES (%s, %s, %s, %s, %s, %s)""",
#      10         (row['place_name'],
#      11          row['place_desc'],
#      12          row['category'],
#      13          row['city'],
#      14          row['rating'],
#      15          row['num_reviews']))
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:151, in Cursor.execute(self, query, args)
#     148 while self.nextset():
#     149     pass
# --> 151 query = self.mogrify(query, args)
#     153 result = self._query(query)
# ...

# %%
#conn.commit()
conn.close()

# %%
file3.drop_duplicates(['place_name'])
# Out:
#                       place_name place_desc category  \
# 0                            이월드                테마파크
# 1   클럽디오아시스(CLUBD OASIS) 스파&워터파크                테마파크
# 2                           금오랜드                테마파크
# 3                           상록랜드                테마파크
# 4                         소노벨 천안                테마파크
# 5                 (주)금호리조트아산스파비스                테마파크
# 6                       호텔마스타 대천                테마파크
# 7                           에버랜드                테마파크
# 8                         캐리비안베이                테마파크
# 9                     한국민속촌 가족공원                테마파크
# 10                9.81 PARK JEJU                테마파크
# 11               경주월드주식회사 (경주지점)                테마파크
# 12                      블루원 워터파크                테마파크
# 13                      아쿠아필드 하남                테마파크
# 14                          하니랜드                테마파크
# 15                      주식회사 썬밸리                테마파크
# 16                     유월드루지테마파크                테마파크
# ...
